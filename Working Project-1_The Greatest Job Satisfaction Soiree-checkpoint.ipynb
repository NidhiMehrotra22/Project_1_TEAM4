# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# NM File path
file_path = "../Project_1_TEAM4/glassdoor_reviews.csv"

# %%
# NM Read File and store into Pandas DataFrames
file_read= pd.read_csv(file_path)
file_read.head()
# Out:
#    Unnamed: 0  column_label       firm date_review  \
# 0           1             1  Sotheby-s  2021-05-25
# 1           2             1  Sotheby-s  2021-05-25
# 2           3             1  Sotheby-s  2021-05-24
# 3           4             1  Sotheby-s  2021-05-22
# 4           5             1  Sotheby-s  2021-05-15
#
#                          job_title                             current  \
# 0                Financial Analyst   Former Employee, more than 1 year
# 1                    Administrator                     Former Employee
# 2   Client Services Representative   Former Employee, more than 1 year
# 3               Anonymous Employee                    Current Employee
# 4                    Administrator  Current Employee, less than 1 year
#
#                    location  overall_rating  work_life_balance  \
# 0              New York, NY               1                1.0
# 1                 Hong Kong               4                4.0
# 2  London, England, England               4                5.0
# 3                 Hong Kong               3                2.0
# 4  London, England, England               4                4.0
#
#    culture_values  ...  career_opp  comp_benefits  senior_mgmt  recommend  \
# 0             1.0  ...         1.0            2.0          1.0          x
# 1             5.0  ...         3.0            4.0          4.0          o
# 2             4.0  ...         5.0            4.0          5.0          v
# 3             2.0  ...         3.0            2.0          3.0          o
# 4             4.0  ...         3.0            3.0          3.0          v
#
#   ceo_approv outlook                                           headline  \
# 0          r       x                                        Don't do it
# 1          o       o                        international auction house
# 2          v       v                Fast-paced, difficult and rewarding
# 3          o       o                                             Review
# 4          r       v  Fun job and nice people but huge workload and ...
#
#                                                 pros  \
# 0  People in leadership roles have been there for...
# 1  great exposure, respectful environment and bea...
# 2                    Good team, support and training
# 3    Exposure to artworks, great team of specialists
# 4  Fantastic art, nice enthusiastic people and a ...
#
#                                                 cons use
# 0  Pressure to do whatever the leaders want\r\nNo... NaN
# 1         OT during peak seasons and often underpaid NaN
# 2       High-stress with relatively low conpensation NaN
# 3                 Work life balance, company culture NaN
# 4                     Very low pay and huge workload NaN
#
# [5 rows x 21 columns]

# %%
# NM show the data type of each column
file_read.dtypes
# Out:
# Unnamed: 0               int64
# column_label             int64
# firm                    object
# date_review             object
# job_title               object
# current                 object
# location                object
# overall_rating           int64
# work_life_balance      float64
# culture_values         float64
# diversity_inclusion    float64
# career_opp             float64
# comp_benefits          float64
# senior_mgmt            float64
# recommend               object
# ceo_approv              object
# outlook                 object
# headline                object
# pros                    object
# cons                    object
# use                    float64
# dtype: object

# %%
#NM Calculate the total number of firms
firm_total= file_read["firm"].nunique()
firm_total
# Out:
# 428

# %%
# NM Calculate the total number of job titles
job_title_total= file_read["job_title"].nunique()
job_title_total
# Out:
# 62275

# %%
# NM Delete the columns which are not useful
file_new= file_read.drop(["column_label","recommend", "ceo_approv","outlook","headline","pros", "cons", "use"], axis=1)
file_new
# Out:
#         Unnamed: 0                              firm date_review  \
# 0                1                         Sotheby-s  2021-05-25
# 1                2                         Sotheby-s  2021-05-25
# 2                3                         Sotheby-s  2021-05-24
# 3                4                         Sotheby-s  2021-05-22
# 4                5                         Sotheby-s  2021-05-15
# ...            ...                               ...         ...
# 838561      838562  Department-for-Work-And-Pensions  2010-09-03
# 838562      838563  Department-for-Work-And-Pensions  2010-04-25
# 838563      838564  Department-for-Work-And-Pensions  2009-11-08
# 838564      838565  Department-for-Work-And-Pensions  2009-07-16
# 838565      838566  Department-for-Work-And-Pensions  2008-12-24
#
#                               job_title                             current  \
# 0                     Financial Analyst   Former Employee, more than 1 year
# 1                         Administrator                     Former Employee
# 2        Client Services Representative   Former Employee, more than 1 year
# 3                    Anonymous Employee                    Current Employee
# 4                         Administrator  Current Employee, less than 1 year
# ...                                 ...                                 ...
# 838561                          Analyst                     Former Employee
# 838562              Assistant Economist                    Current Employee
# 838563                Private Secretary                    Current Employee
# 838564                   DASO Jobcentre                    Current Employee
# 838565                              CSO                    Current Employee
#
#                               location  overall_rating  work_life_balance  \
# 0                         New York, NY               1                1.0
# 1                            Hong Kong               4                4.0
# 2             London, England, England               4                5.0
# 3                            Hong Kong               3                2.0
# 4             London, England, England               4                4.0
# ...                                ...             ...                ...
# 838561        London, England, England               2                4.0
# 838562        London, England, England               3                5.0
# 838563        London, England, England               4                4.0
# 838564  Newport, Newport, Wales, Wales               4                5.0
# 838565                             NaN               2                2.0
#
#         culture_values  diversity_inclusion  career_opp  comp_benefits  \
# 0                  1.0                  1.0         1.0            2.0
# 1                  5.0                  4.0         3.0            4.0
# 2                  4.0                  4.0         5.0            4.0
# 3                  2.0                  3.0         3.0            2.0
# 4                  4.0                  3.0         3.0            3.0
# ...                ...                  ...         ...            ...
# 838561             NaN                  NaN         2.0            2.0
# 838562             NaN                  NaN         5.0            1.0
# 838563             NaN                  NaN         4.0            2.0
# 838564             NaN                  NaN         3.0            3.0
# 838565             NaN                  NaN         2.0            1.0
#
#         senior_mgmt
# 0               1.0
# 1               4.0
# 2               5.0
# 3               3.0
# 4               3.0
# ...             ...
# 838561          3.0
# 838562          2.0
# 838563          3.0
# 838564          2.0
# 838565          1.0
#
# [838566 rows x 13 columns]

# %%
# NM Filter data by "firm" using groupby method
firm_group= file_new.groupby(["firm"])
firm_group

# %%
#NM Count number of "job title" in each firm 
firm_group["job_title"].count()
# Out:
# firm
# AFH-Wealth-Management      63
# AJ-Bell                   114
# ALDI                      931
# AQA                       114
# ASDA                     4760
#                          ...
# i-Net-Solution              4
# ibis                      120
# mydentist-UK               95
# next                     3324
# the-LEGO-Group            824
# Name: job_title, Length: 428, dtype: int64

# %%
# NM Calculate Mean of the ratings based on the firms
job_satis_df = firm_group["overall_rating","work_life_balance","culture_values","diversity_inclusion","career_opp","comp_benefits","senior_mgmt"].mean()
job_satis_df
# Out:
# C:\Users\jonow\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                        overall_rating  work_life_balance  culture_values  \
# firm
# AFH-Wealth-Management        2.904762           3.500000        2.964912
# AJ-Bell                      3.359649           3.561905        3.514286
# ALDI                         3.422127           2.579674        3.115723
# AQA                          3.622807           3.694737        3.425532
# ASDA                         3.352521           3.108824        3.184744
# ...                               ...                ...             ...
# i-Net-Solution               4.000000           3.666667        3.666667
# ibis                         3.358333           2.937500        3.221053
# mydentist-UK                 3.305263           3.309524        3.202381
# next                         3.358303           3.229527        3.141359
# the-LEGO-Group               3.986650           3.965753        4.293952
#
#                        diversity_inclusion  career_opp  comp_benefits  \
# firm
# AFH-Wealth-Management             3.000000    2.872727       2.803571
# AJ-Bell                           3.027027    3.304762       3.028571
# ALDI                              3.562992    3.198254       3.389724
# AQA                               3.777778    2.723404       3.168421
# ASDA                              3.684796    2.916867       3.050497
# ...                                    ...         ...            ...
# i-Net-Solution                         NaN    3.000000       3.000000
# ibis                              3.583333    3.135417       2.947917
# mydentist-UK                      3.000000    3.238095       2.857143
# next                              3.705986    2.839954       3.048884
# the-LEGO-Group                    4.190789    3.241758       3.668508
#
#                        senior_mgmt
# firm
# AFH-Wealth-Management     2.807018
# AJ-Bell                   3.142857
# ALDI                      2.998742
# AQA                       2.882979
# ASDA                      2.754372
# ...                            ...
# i-Net-Solution            3.333333
# ibis                      2.821053
# mydentist-UK              3.071429
# next                      2.948243
# the-LEGO-Group            3.459834
#
# [428 rows x 7 columns]

# %%
# NM Replace NaN/None Values with Zero
job_satis_na_df = job_satis_df.fillna(0)
job_satis_na_df
# Out:
#                        overall_rating  work_life_balance  culture_values  \
# firm
# AFH-Wealth-Management        2.904762           3.500000        2.964912
# AJ-Bell                      3.359649           3.561905        3.514286
# ALDI                         3.422127           2.579674        3.115723
# AQA                          3.622807           3.694737        3.425532
# ASDA                         3.352521           3.108824        3.184744
# ...                               ...                ...             ...
# i-Net-Solution               4.000000           3.666667        3.666667
# ibis                         3.358333           2.937500        3.221053
# mydentist-UK                 3.305263           3.309524        3.202381
# next                         3.358303           3.229527        3.141359
# the-LEGO-Group               3.986650           3.965753        4.293952
#
#                        diversity_inclusion  career_opp  comp_benefits  \
# firm
# AFH-Wealth-Management             3.000000    2.872727       2.803571
# AJ-Bell                           3.027027    3.304762       3.028571
# ALDI                              3.562992    3.198254       3.389724
# AQA                               3.777778    2.723404       3.168421
# ASDA                              3.684796    2.916867       3.050497
# ...                                    ...         ...            ...
# i-Net-Solution                    0.000000    3.000000       3.000000
# ibis                              3.583333    3.135417       2.947917
# mydentist-UK                      3.000000    3.238095       2.857143
# next                              3.705986    2.839954       3.048884
# the-LEGO-Group                    4.190789    3.241758       3.668508
#
#                        senior_mgmt
# firm
# AFH-Wealth-Management     2.807018
# AJ-Bell                   3.142857
# ALDI                      2.998742
# AQA                       2.882979
# ASDA                      2.754372
# ...                            ...
# i-Net-Solution            3.333333
# ibis                      2.821053
# mydentist-UK              3.071429
# next                      2.948243
# the-LEGO-Group            3.459834
#
# [428 rows x 7 columns]

# %%
# NM nsmallest() helps to get the smallest numbers from a variable or from a dataset.
overall_rating_lowest= job_satis_na_df.nsmallest(n=5, columns=['overall_rating'])
overall_rating_lowest
# Out:
#                               overall_rating  work_life_balance  \
# firm
# The-Range                           2.200000           2.236842
# Creative-Support                    2.257778           2.106599
# James-Hay-Partnership               2.311111           2.645570
# Macdonald-Hotels-and-Resorts        2.330472           2.173709
# Diligenta                           2.363636           2.847826
#
#                               culture_values  diversity_inclusion  career_opp  \
# firm
# The-Range                           1.946667             2.734513    2.097884
# Creative-Support                    2.472081             3.333333    2.296482
# James-Hay-Partnership               2.287500             3.428571    2.125000
# Macdonald-Hotels-and-Resorts        2.188679             3.300000    2.391509
# Diligenta                           2.195652             2.759259    1.920290
#
#                               comp_benefits  senior_mgmt
# firm
# The-Range                          1.770667     1.954667
# Creative-Support                   2.030612     2.139175
# James-Hay-Partnership              2.587500     2.000000
# Macdonald-Hotels-and-Resorts       2.300469     2.080569
# Diligenta                          1.942029     2.072464

# %%
# NM nlargest () helps to get the highest numbers from a variable or from a dataset.
overall_rating_largest= job_satis_na_df.nlargest(n=5, columns=['overall_rating'])
overall_rating_largest
# Out:
#                         overall_rating  work_life_balance  culture_values  \
# firm
# The-Survey-Association        5.000000           3.333333        4.666667
# Time-Etc                      4.785714           4.700000        4.775000
# Northern-Gas-and-Power        4.719682           4.750000        4.708075
# CarShop-UK                    4.651163           4.127572        4.597510
# Michelmores                   4.610390           4.588235        4.632353
#
#                         diversity_inclusion  career_opp  comp_benefits  \
# firm
# The-Survey-Association             5.000000    4.666667       4.000000
# Time-Etc                           4.777778    4.658537       4.410256
# Northern-Gas-and-Power             4.517241    4.688660       4.756198
# CarShop-UK                         4.363636    4.553719       4.508264
# Michelmores                        4.000000    4.382353       4.323529
#
#                         senior_mgmt
# firm
# The-Survey-Association     3.666667
# Time-Etc                   4.789474
# Northern-Gas-and-Power     4.683884
# CarShop-UK                 4.576763
# Michelmores                4.313433

# %%
# NM Generate a bar plot to compare the Bottom 5 Firms Overall Rating vs their various work environment factors
x_axis= np.arange(len(overall_rating_lowest))
ticks= list(overall_rating_lowest.index.values)
tick_locations= [value +0.4 for value in x_axis]
plt.xticks(tick_locations, ticks,rotation="90")
overall = plt.bar(x_axis +0.13, overall_rating_lowest["overall_rating"], width=0.12, label = "Overall Rating", color="red", alpha=0.75, align="center")
wlb = plt.bar(x_axis +0.25, overall_rating_lowest["work_life_balance"], width=0.12, label = "Work Life Balance", color="b", alpha=0.75, align="center")
cul_val = plt.bar(x_axis +0.35, overall_rating_lowest["culture_values"], width=0.12, label = "Culture values", color="g", alpha=0.75, align="center")
div_inc = plt.bar(x_axis +0.45, overall_rating_lowest["diversity_inclusion"], width=0.12, label = "Diversity inclusion", color="orange", alpha=0.75, align="center")
carrer_opp = plt.bar(x_axis +0.55, overall_rating_lowest["career_opp"], width=0.12, label = "Career opportunities", color="y", alpha=0.75, align="center")
comp_ben = plt.bar(x_axis +0.65, overall_rating_lowest["comp_benefits"], width=0.12, label = "Company benefits", color="purple", alpha=0.75, align="center")
senior_mgt= plt.bar(x_axis +0.75, overall_rating_lowest["senior_mgmt"], width=0.12, label = 'Senior management', color="cyan", alpha=0.75, align="center")
plt.xlim(-0.5, len(x_axis))
plt.ylim(0,4 + 0.25)
plt.legend(handles = [overall,wlb,cul_val,div_inc,carrer_opp,comp_ben,senior_mgt ], loc = "best", bbox_to_anchor = (1.0, 1.0))
plt.title("Bottom 5 Firms Overall Rating vs Work environment factor")
plt.figure(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
# # NM Generate a bar plot to compare the Top 5 Firms Overall Rating vs their various work environment factors
x_axis= np.arange(len(overall_rating_largest))
ticks= list(overall_rating_largest.index.values)
tick_locations= [value +0.4 for value in x_axis]
plt.xticks(tick_locations, ticks,rotation="90")
overall = plt.bar(x_axis +0.13, overall_rating_largest["overall_rating"], width=0.12, label = "Overall Rating", color="red", alpha=0.75, align="center")
wlb = plt.bar(x_axis +0.25, overall_rating_largest["work_life_balance"], width=0.12, label = "Work Life Balance", color="b", alpha=0.75, align="center")
cul_val = plt.bar(x_axis +0.35, overall_rating_largest["culture_values"], width=0.12, label = "Culture values", color="g", alpha=0.75, align="center")
div_inc = plt.bar(x_axis +0.45, overall_rating_largest["diversity_inclusion"], width=0.12, label = "Diversity inclusion", color="orange", alpha=0.75, align="center")
carrer_opp = plt.bar(x_axis +0.55, overall_rating_largest["career_opp"], width=0.12, label = "Career opportunities", color="y", alpha=0.75, align="center")
comp_ben = plt.bar(x_axis +0.65, overall_rating_largest["comp_benefits"], width=0.12, label = "Company benefits", color="purple", alpha=0.75, align="center")
senior_mgt= plt.bar(x_axis +0.75, overall_rating_largest["senior_mgmt"], width=0.12, label = 'Senior management', color="cyan", alpha=0.75, align="center")
plt.xlim(-0.5, len(x_axis))
plt.ylim(0,5 + 0.5)
plt.legend(handles = [overall,wlb,cul_val,div_inc,carrer_opp,comp_ben,senior_mgt ], loc = "best", bbox_to_anchor = (1.0, 1.0))
plt.title("Top 5 Firms Overall Rating v/s Work environment factor")
plt.figure(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
# # NM
file_new["year"]= pd.Series(file_new["date_review"]).str.slice(stop=4)
file_new["month"]= pd.Series(file_new["date_review"]).str.slice(start=5,stop=7)
file_new["day"]= pd.Series(file_new["date_review"]).str.slice(start=8,stop=10)
file_new
# Out:
#         Unnamed: 0                              firm date_review  \
# 0                1                         Sotheby-s  2021-05-25
# 1                2                         Sotheby-s  2021-05-25
# 2                3                         Sotheby-s  2021-05-24
# 3                4                         Sotheby-s  2021-05-22
# 4                5                         Sotheby-s  2021-05-15
# ...            ...                               ...         ...
# 838561      838562  Department-for-Work-And-Pensions  2010-09-03
# 838562      838563  Department-for-Work-And-Pensions  2010-04-25
# 838563      838564  Department-for-Work-And-Pensions  2009-11-08
# 838564      838565  Department-for-Work-And-Pensions  2009-07-16
# 838565      838566  Department-for-Work-And-Pensions  2008-12-24
#
#                               job_title                             current  \
# 0                     Financial Analyst   Former Employee, more than 1 year
# 1                         Administrator                     Former Employee
# 2        Client Services Representative   Former Employee, more than 1 year
# 3                    Anonymous Employee                    Current Employee
# 4                         Administrator  Current Employee, less than 1 year
# ...                                 ...                                 ...
# 838561                          Analyst                     Former Employee
# 838562              Assistant Economist                    Current Employee
# 838563                Private Secretary                    Current Employee
# 838564                   DASO Jobcentre                    Current Employee
# 838565                              CSO                    Current Employee
#
#                               location  overall_rating  work_life_balance  \
# 0                         New York, NY               1                1.0
# 1                            Hong Kong               4                4.0
# 2             London, England, England               4                5.0
# 3                            Hong Kong               3                2.0
# 4             London, England, England               4                4.0
# ...                                ...             ...                ...
# 838561        London, England, England               2                4.0
# 838562        London, England, England               3                5.0
# 838563        London, England, England               4                4.0
# 838564  Newport, Newport, Wales, Wales               4                5.0
# 838565                             NaN               2                2.0
#
#         culture_values  diversity_inclusion  career_opp  comp_benefits  \
# 0                  1.0                  1.0         1.0            2.0
# 1                  5.0                  4.0         3.0            4.0
# 2                  4.0                  4.0         5.0            4.0
# 3                  2.0                  3.0         3.0            2.0
# 4                  4.0                  3.0         3.0            3.0
# ...                ...                  ...         ...            ...
# 838561             NaN                  NaN         2.0            2.0
# 838562             NaN                  NaN         5.0            1.0
# 838563             NaN                  NaN         4.0            2.0
# 838564             NaN                  NaN         3.0            3.0
# 838565             NaN                  NaN         2.0            1.0
#
#         senior_mgmt  year month day
# 0               1.0  2021    05  25
# 1               4.0  2021    05  25
# 2               5.0  2021    05  24
# 3               3.0  2021    05  22
# 4               3.0  2021    05  15
# ...             ...   ...   ...  ..
# 838561          3.0  2010    09  03
# 838562          2.0  2010    04  25
# 838563          3.0  2009    11  08
# 838564          2.0  2009    07  16
# 838565          1.0  2008    12  24
#
# [838566 rows x 16 columns]

# %%
# # NM
file_new= file_new.drop(["date_review","month", "day"], axis=1)
file_new
# Out:
#         Unnamed: 0                              firm  \
# 0                1                         Sotheby-s
# 1                2                         Sotheby-s
# 2                3                         Sotheby-s
# 3                4                         Sotheby-s
# 4                5                         Sotheby-s
# ...            ...                               ...
# 838561      838562  Department-for-Work-And-Pensions
# 838562      838563  Department-for-Work-And-Pensions
# 838563      838564  Department-for-Work-And-Pensions
# 838564      838565  Department-for-Work-And-Pensions
# 838565      838566  Department-for-Work-And-Pensions
#
#                               job_title                             current  \
# 0                     Financial Analyst   Former Employee, more than 1 year
# 1                         Administrator                     Former Employee
# 2        Client Services Representative   Former Employee, more than 1 year
# 3                    Anonymous Employee                    Current Employee
# 4                         Administrator  Current Employee, less than 1 year
# ...                                 ...                                 ...
# 838561                          Analyst                     Former Employee
# 838562              Assistant Economist                    Current Employee
# 838563                Private Secretary                    Current Employee
# 838564                   DASO Jobcentre                    Current Employee
# 838565                              CSO                    Current Employee
#
#                               location  overall_rating  work_life_balance  \
# 0                         New York, NY               1                1.0
# 1                            Hong Kong               4                4.0
# 2             London, England, England               4                5.0
# 3                            Hong Kong               3                2.0
# 4             London, England, England               4                4.0
# ...                                ...             ...                ...
# 838561        London, England, England               2                4.0
# 838562        London, England, England               3                5.0
# 838563        London, England, England               4                4.0
# 838564  Newport, Newport, Wales, Wales               4                5.0
# 838565                             NaN               2                2.0
#
#         culture_values  diversity_inclusion  career_opp  comp_benefits  \
# 0                  1.0                  1.0         1.0            2.0
# 1                  5.0                  4.0         3.0            4.0
# 2                  4.0                  4.0         5.0            4.0
# 3                  2.0                  3.0         3.0            2.0
# 4                  4.0                  3.0         3.0            3.0
# ...                ...                  ...         ...            ...
# 838561             NaN                  NaN         2.0            2.0
# 838562             NaN                  NaN         5.0            1.0
# 838563             NaN                  NaN         4.0            2.0
# 838564             NaN                  NaN         3.0            3.0
# 838565             NaN                  NaN         2.0            1.0
#
#         senior_mgmt  year
# 0               1.0  2021
# 1               4.0  2021
# 2               5.0  2021
# 3               3.0  2021
# 4               3.0  2021
# ...             ...   ...
# 838561          3.0  2010
# 838562          2.0  2010
# 838563          3.0  2009
# 838564          2.0  2009
# 838565          1.0  2008
#
# [838566 rows x 13 columns]

# %%
# # NM
firm_year_df= file_new.loc[file_new["firm"].isin(["Accenture","the-LEGO-Group"]), :]
firm_year_df
# Out:
#         Unnamed: 0            firm                         job_title  \
# 28297        28298  the-LEGO-Group   Customer Service Representative
# 28298        28299  the-LEGO-Group        Human Resources Specialist
# 28299        28300  the-LEGO-Group                        Strategist
# 28300        28301  the-LEGO-Group                   Sales Associate
# 28301        28302  the-LEGO-Group                 Marketing Manager
# ...            ...             ...                               ...
# 634608      634609       Accenture                        Consultant
# 634609      634610       Accenture                        Consultant
# 634610      634611       Accenture                    Senior Manager
# 634611      634612       Accenture       Outsourcing Sales Executive
# 634612      634613       Accenture
#
#                                     current  \
# 28297    Current Employee, less than 1 year
# 28298   Current Employee, more than 3 years
# 28299                      Current Employee
# 28300    Current Employee, less than 1 year
# 28301   Current Employee, more than 5 years
# ...                                     ...
# 634608                     Current Employee
# 634609                     Current Employee
# 634610                     Current Employee
# 634611                     Current Employee
# 634612                     Current Employee
#
#                                           location  overall_rating  \
# 28297                                          NaN               5
# 28298   Kladno, Central Bohemian, Central Bohemian               5
# 28299                                          NaN               4
# 28300                     London, England, England               3
# 28301                    München, Bavaria, Bavaria               5
# ...                                            ...             ...
# 634608                    London, England, England               3
# 634609                    London, England, England               4
# 634610                    London, England, England               4
# 634611                    London, England, England               3
# 634612                Manchester, England, England               3
#
#         work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 28297                 NaN             NaN                  NaN         NaN
# 28298                 4.0             5.0                  4.0         4.0
# 28299                 5.0             5.0                  5.0         3.0
# 28300                 NaN             NaN                  NaN         NaN
# 28301                 4.0             5.0                  4.0         4.0
# ...                   ...             ...                  ...         ...
# 634608                2.0             NaN                  NaN         4.0
# 634609                3.0             NaN                  NaN         4.0
# 634610                4.0             NaN                  NaN         4.0
# 634611                5.0             NaN                  NaN         3.0
# 634612                1.0             NaN                  NaN         3.0
#
#         comp_benefits  senior_mgmt  year
# 28297             NaN          NaN  2021
# 28298             5.0          5.0  2021
# 28299             5.0          3.0  2021
# 28300             NaN          NaN  2021
# 28301             4.0          4.0  2021
# ...               ...          ...   ...
# 634608            3.0          4.0  2008
# 634609            2.0          4.0  2008
# 634610            4.0          4.0  2008
# 634611            3.0          2.0  2008
# 634612            4.0          1.0  2008
#
# [2980 rows x 13 columns]

# %%
# # JW
lego_df= file_new.loc[file_new["firm"].isin(["the-LEGO-Group"]), :]
lego_df
# Out:
#        Unnamed: 0            firm                         job_title  \
# 28297       28298  the-LEGO-Group   Customer Service Representative
# 28298       28299  the-LEGO-Group        Human Resources Specialist
# 28299       28300  the-LEGO-Group                        Strategist
# 28300       28301  the-LEGO-Group                   Sales Associate
# 28301       28302  the-LEGO-Group                 Marketing Manager
# ...           ...             ...                               ...
# 29116       29117  the-LEGO-Group                    Special Events
# 29117       29118  the-LEGO-Group         Consumer Services Advisor
# 29118       29119  the-LEGO-Group
# 29119       29120  the-LEGO-Group
# 29120       29121  the-LEGO-Group
#
#                                    current  \
# 28297   Current Employee, less than 1 year
# 28298  Current Employee, more than 3 years
# 28299                     Current Employee
# 28300   Current Employee, less than 1 year
# 28301  Current Employee, more than 5 years
# ...                                    ...
# 29116                     Current Employee
# 29117                      Former Employee
# 29118                      Former Employee
# 29119                     Current Employee
# 29120                     Current Employee
#
#                                          location  overall_rating  \
# 28297                                         NaN               5
# 28298  Kladno, Central Bohemian, Central Bohemian               5
# 28299                                         NaN               4
# 28300                    London, England, England               3
# 28301                   München, Bavaria, Bavaria               5
# ...                                           ...             ...
# 29116                                         NaN               2
# 29117                                 Enfield, CT               1
# 29118                                 Enfield, CT               3
# 29119                                         NaN               4
# 29120                                Columbus, OH               4
#
#        work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 28297                NaN             NaN                  NaN         NaN
# 28298                4.0             5.0                  4.0         4.0
# 28299                5.0             5.0                  5.0         3.0
# 28300                NaN             NaN                  NaN         NaN
# 28301                4.0             5.0                  4.0         4.0
# ...                  ...             ...                  ...         ...
# 29116                4.0             NaN                  NaN         1.0
# 29117                2.0             NaN                  NaN         1.0
# 29118                3.0             NaN                  NaN         2.0
# 29119                4.0             NaN                  NaN         4.0
# 29120                4.0             NaN                  NaN         4.0
#
#        comp_benefits  senior_mgmt  year
# 28297            NaN          NaN  2021
# 28298            5.0          5.0  2021
# 28299            5.0          3.0  2021
# 28300            NaN          NaN  2021
# 28301            4.0          4.0  2021
# ...              ...          ...   ...
# 29116            2.0          2.0  2011
# 29117            1.0          1.0  2011
# 29118            3.0          2.0  2011
# 29119            2.0          4.0  2010
# 29120            3.0          1.0  2010
#
# [824 rows x 13 columns]

# %%
accenture_df= file_new.loc[file_new["firm"].isin(["Accenture"]), :]
accenture_df
# Out:
#         Unnamed: 0       firm                     job_title  \
# 632457      632458  Accenture   Data Science Senior Manager
# 632458      632459  Accenture              Strategy Manager
# 632459      632460  Accenture                   PMO Manager
# 632460      632461  Accenture        Senior Pricing Analyst
# 632461      632462  Accenture                Senior Analyst
# ...            ...        ...                           ...
# 634608      634609  Accenture                    Consultant
# 634609      634610  Accenture                    Consultant
# 634610      634611  Accenture                Senior Manager
# 634611      634612  Accenture   Outsourcing Sales Executive
# 634612      634613  Accenture
#
#                                     current                      location  \
# 632457  Current Employee, more than 5 years      London, England, England
# 632458  Current Employee, more than 8 years  Manchester, England, England
# 632459                      Former Employee   Glasgow, Scotland, Scotland
# 632460   Former Employee, more than 5 years      London, England, England
# 632461   Current Employee, more than 1 year      London, England, England
# ...                                     ...                           ...
# 634608                     Current Employee      London, England, England
# 634609                     Current Employee      London, England, England
# 634610                     Current Employee      London, England, England
# 634611                     Current Employee      London, England, England
# 634612                     Current Employee  Manchester, England, England
#
#         overall_rating  work_life_balance  culture_values  \
# 632457               4                NaN             NaN
# 632458               5                3.0             5.0
# 632459               3                1.0             2.0
# 632460               4                2.0             4.0
# 632461               4                2.0             3.0
# ...                ...                ...             ...
# 634608               3                2.0             NaN
# 634609               4                3.0             NaN
# 634610               4                4.0             NaN
# 634611               3                5.0             NaN
# 634612               3                1.0             NaN
#
#         diversity_inclusion  career_opp  comp_benefits  senior_mgmt  year
# 632457                  NaN         NaN            NaN          NaN  2021
# 632458                  5.0         5.0            4.0          4.0  2021
# 632459                  2.0         2.0            2.0          3.0  2021
# 632460                  5.0         4.0            4.0          3.0  2021
# 632461                  5.0         4.0            3.0          4.0  2021
# ...                     ...         ...            ...          ...   ...
# 634608                  NaN         4.0            3.0          4.0  2008
# 634609                  NaN         4.0            2.0          4.0  2008
# 634610                  NaN         4.0            4.0          4.0  2008
# 634611                  NaN         3.0            3.0          2.0  2008
# 634612                  NaN         3.0            4.0          1.0  2008
#
# [2156 rows x 13 columns]

# %%
# # JW
lego_loc= lego_df.groupby(["location"])
accenture_loc = accenture_df.groupby(["location"])
lego_loc.head()
# Out:
#        Unnamed: 0            firm                         job_title  \
# 28297       28298  the-LEGO-Group   Customer Service Representative
# 28298       28299  the-LEGO-Group        Human Resources Specialist
# 28299       28300  the-LEGO-Group                        Strategist
# 28300       28301  the-LEGO-Group                   Sales Associate
# 28301       28302  the-LEGO-Group                 Marketing Manager
# ...           ...             ...                               ...
# 29094       29095  the-LEGO-Group                   Sales Associate
# 29098       29099  the-LEGO-Group                   Sales Associate
# 29099       29100  the-LEGO-Group                 Digital Marketing
# 29108       29109  the-LEGO-Group                   Sales Associate
# 29120       29121  the-LEGO-Group
#
#                                    current  \
# 28297   Current Employee, less than 1 year
# 28298  Current Employee, more than 3 years
# 28299                     Current Employee
# 28300   Current Employee, less than 1 year
# 28301  Current Employee, more than 5 years
# ...                                    ...
# 29094    Former Employee, more than 1 year
# 29098    Former Employee, less than 1 year
# 29099   Former Employee, more than 8 years
# 29108                      Former Employee
# 29120                     Current Employee
#
#                                          location  overall_rating  \
# 28297                                         NaN               5
# 28298  Kladno, Central Bohemian, Central Bohemian               5
# 28299                                         NaN               4
# 28300                    London, England, England               3
# 28301                   München, Bavaria, Bavaria               5
# ...                                           ...             ...
# 29094                             Friendswood, TX               4
# 29098                                  Vernon, CA               1
# 29099                                Industry, CA               3
# 29108                             Friendswood, TX               1
# 29120                                Columbus, OH               4
#
#        work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 28297                NaN             NaN                  NaN         NaN
# 28298                4.0             5.0                  4.0         4.0
# 28299                5.0             5.0                  5.0         3.0
# 28300                NaN             NaN                  NaN         NaN
# 28301                4.0             5.0                  4.0         4.0
# ...                  ...             ...                  ...         ...
# 29094                4.0             3.0                  NaN         3.0
# 29098                1.0             1.0                  NaN         1.0
# 29099                4.0             3.0                  NaN         2.0
# 29108                2.0             NaN                  NaN         1.0
# 29120                4.0             NaN                  NaN         4.0
#
#        comp_benefits  senior_mgmt  year
# 28297            NaN          NaN  2021
# 28298            5.0          5.0  2021
# 28299            5.0          3.0  2021
# 28300            NaN          NaN  2021
# 28301            4.0          4.0  2021
# ...              ...          ...   ...
# 29094            3.0          2.0  2012
# 29098            1.0          1.0  2012
# 29099            3.0          2.0  2012
# 29108            1.0          1.0  2011
# 29120            3.0          1.0  2010
#
# [287 rows x 13 columns]

# %%
# # NM
firm_group_year= firm_year_df.groupby(["firm","year"])
firm_group_year.head()
# Out:
#         Unnamed: 0            firm                         job_title  \
# 28297        28298  the-LEGO-Group   Customer Service Representative
# 28298        28299  the-LEGO-Group        Human Resources Specialist
# 28299        28300  the-LEGO-Group                        Strategist
# 28300        28301  the-LEGO-Group                   Sales Associate
# 28301        28302  the-LEGO-Group                 Marketing Manager
# ...            ...             ...                               ...
# 634580      634581       Accenture                 Senior Consultant
# 634581      634582       Accenture                        Consultant
# 634582      634583       Accenture                        Consultant
# 634583      634584       Accenture                           Manager
# 634584      634585       Accenture                           Analyst
#
#                                     current  \
# 28297    Current Employee, less than 1 year
# 28298   Current Employee, more than 3 years
# 28299                      Current Employee
# 28300    Current Employee, less than 1 year
# 28301   Current Employee, more than 5 years
# ...                                     ...
# 634580                      Former Employee
# 634581                     Current Employee
# 634582                     Current Employee
# 634583                      Former Employee
# 634584                     Current Employee
#
#                                           location  overall_rating  \
# 28297                                          NaN               5
# 28298   Kladno, Central Bohemian, Central Bohemian               5
# 28299                                          NaN               4
# 28300                     London, England, England               3
# 28301                    München, Bavaria, Bavaria               5
# ...                                            ...             ...
# 634580                    London, England, England               3
# 634581                    London, England, England               3
# 634582                    London, England, England               4
# 634583                    London, England, England               2
# 634584                    London, England, England               4
#
#         work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 28297                 NaN             NaN                  NaN         NaN
# 28298                 4.0             5.0                  4.0         4.0
# 28299                 5.0             5.0                  5.0         3.0
# 28300                 NaN             NaN                  NaN         NaN
# 28301                 4.0             5.0                  4.0         4.0
# ...                   ...             ...                  ...         ...
# 634580                2.0             NaN                  NaN         3.0
# 634581                2.0             NaN                  NaN         3.0
# 634582                4.0             NaN                  NaN         4.0
# 634583                3.0             NaN                  NaN         3.0
# 634584                3.0             NaN                  NaN         4.0
#
#         comp_benefits  senior_mgmt  year
# 28297             NaN          NaN  2021
# 28298             5.0          5.0  2021
# 28299             5.0          3.0  2021
# 28300             NaN          NaN  2021
# 28301             4.0          4.0  2021
# ...               ...          ...   ...
# 634580            3.0          3.0  2008
# 634581            3.0          3.0  2008
# 634582            4.0          3.0  2008
# 634583            2.0          1.0  2008
# 634584            4.0          4.0  2008
#
# [127 rows x 13 columns]

# %%
accenture_loc_df = accenture_loc["overall_rating", "work_life_balance","culture_values"].mean()
accenture_loc_df
# Out:
# C:\Users\jonow\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                                   overall_rating  \
# location
# Aberdeen, Scotland, Scotland                            4.500000
# Anacortes, WA                                           2.000000
# Austin, TX                                              3.666667
# Bangalore                                               4.000000
# Belfast, Northern Ireland, Northern Ireland             5.000000
# ...                                                          ...
# Warrington, North West England, England, England        4.000000
# Warwick, West Midlands, England, England                3.800000
# Wilmslow, England, England                              5.000000
# Winnersh, England, England                              1.000000
# Worthing, South East England, England, England          5.000000
#
#                                                   work_life_balance  \
# location
# Aberdeen, Scotland, Scotland                               3.000000
# Anacortes, WA                                              1.000000
# Austin, TX                                                 2.333333
# Bangalore                                                  2.000000
# Belfast, Northern Ireland, Northern Ireland                5.000000
# ...                                                             ...
# Warrington, North West England, England, England           3.000000
# Warwick, West Midlands, England, England                   3.800000
# Wilmslow, England, England                                 4.000000
# Winnersh, England, England                                 1.000000
# Worthing, South East England, England, England             4.000000
#
#                                                   culture_values
# location
# Aberdeen, Scotland, Scotland                            4.500000
# Anacortes, WA                                                NaN
# Austin, TX                                              3.333333
# Bangalore                                               3.500000
# Belfast, Northern Ireland, Northern Ireland             5.000000
# ...                                                          ...
# Warrington, North West England, England, England        4.000000
# Warwick, West Midlands, England, England                4.200000
# Wilmslow, England, England                              5.000000
# Winnersh, England, England                              2.000000
# Worthing, South East England, England, England          4.000000
#
# [79 rows x 3 columns]

# %%
# JW
lego_loc_df = lego_loc["overall_rating", "work_life_balance","culture_values"].mean()
lego_loc_df
# Out:
# C:\Users\jonow\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                                overall_rating  \
# location
# Aarhus                                               4.000000
# Amsterdam                                            4.000000
# Anaheim, CA                                          4.000000
# Anchorage, AK                                        4.000000
# Atlanta, GA                                          2.000000
# ...                                                       ...
# Wijnegem, Antwerp                                    4.000000
# Windsor, South East England, England, England        3.666667
# Windsor, South West England, England, England        3.000000
# Woking, England, England                             5.000000
# Woodbridge, VA                                       5.000000
#
#                                                work_life_balance  \
# location
# Aarhus                                                       3.0
# Amsterdam                                                    4.0
# Anaheim, CA                                                  3.0
# Anchorage, AK                                                5.0
# Atlanta, GA                                                  2.0
# ...                                                          ...
# Wijnegem, Antwerp                                            5.0
# Windsor, South East England, England, England                3.5
# Windsor, South West England, England, England                2.0
# Woking, England, England                                     4.0
# Woodbridge, VA                                               5.0
#
#                                                culture_values
# location
# Aarhus                                               4.500000
# Amsterdam                                            5.000000
# Anaheim, CA                                          3.666667
# Anchorage, AK                                        5.000000
# Atlanta, GA                                          2.000000
# ...                                                       ...
# Wijnegem, Antwerp                                    5.000000
# Windsor, South East England, England, England        3.600000
# Windsor, South West England, England, England        4.000000
# Woking, England, England                             5.000000
# Woodbridge, VA                                       5.000000
#
# [152 rows x 3 columns]

# %%
# # NM
firm_group_rating_yearly= firm_group_year["overall_rating","work_life_balance","culture_values","diversity_inclusion","career_opp","comp_benefits","senior_mgmt"].mean()
firm_group_rating_yearly
# Out:
# C:\Users\jonow\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                      overall_rating  work_life_balance  culture_values  \
# firm           year
# Accenture      2008        3.151515           2.757576             NaN
#                2009        3.138889           3.055556             NaN
#                2010        3.088889           2.888889             NaN
#                2011        3.095238           3.142857             NaN
#                2012        3.530303           2.909091        3.309524
#                2013        3.814815           2.935897        3.779221
#                2014        3.500000           2.887500        3.362500
#                2015        3.717791           2.770701        3.576923
#                2016        3.844221           3.100000        3.788360
#                2017        3.641711           3.033149        3.549451
#                2018        3.626667           3.055172        3.655172
#                2019        3.801020           3.091398        3.745946
#                2020        3.885714           3.158501        3.755747
#                2021        3.830317           3.093093        3.702703
# the-LEGO-Group 2010        4.000000           4.000000             NaN
#                2011        2.692308           3.076923             NaN
#                2012        3.200000           3.357143        3.500000
#                2013        3.571429           4.000000        4.000000
#                2014        3.882353           3.617021        4.148936
#                2015        3.714286           3.705882        4.019231
#                2016        4.068966           3.710526        4.381579
#                2017        3.639175           3.977011        4.174419
#                2018        3.670103           3.816092        4.080460
#                2019        4.104651           4.128205        4.397436
#                2020        4.373418           4.361111        4.510490
#                2021        4.297872           4.061404        4.443478
#
#                      diversity_inclusion  career_opp  comp_benefits  \
# firm           year
# Accenture      2008                  NaN    3.212121       3.000000
#                2009                  NaN    3.083333       3.194444
#                2010                  NaN    3.133333       2.866667
#                2011                  NaN    3.000000       3.047619
#                2012                  NaN    3.696970       3.318182
#                2013                  NaN    3.820513       3.512821
#                2014                  NaN    3.775000       3.387500
#                2015                  NaN    3.735849       3.356688
#                2016                  NaN    3.910995       3.636842
#                2017                  NaN    3.823204       3.532967
#                2018                  NaN    3.737931       3.489655
#                2019                  NaN    3.881081       3.725806
#                2020             4.075188    3.968571       3.644699
#                2021             4.087879    3.873874       3.571856
# the-LEGO-Group 2010                  NaN    4.000000       2.500000
#                2011                  NaN    2.153846       2.384615
#                2012                  NaN    2.785714       3.000000
#                2013                  NaN    3.058824       3.176471
#                2014                  NaN    3.085106       3.355556
#                2015                  NaN    2.961538       3.215686
#                2016                  NaN    3.173333       3.653333
#                2017                  NaN    3.058140       3.534884
#                2018                  NaN    2.988506       3.436782
#                2019                  NaN    3.153846       3.740260
#                2020             4.050000    3.654930       4.062937
#                2021             4.241071    3.547826       4.061404
#
#                      senior_mgmt
# firm           year
# Accenture      2008     3.000000
#                2009     2.916667
#                2010     2.933333
#                2011     3.238095
#                2012     3.242424
#                2013     3.363636
#                2014     3.225000
#                2015     3.303226
#                2016     3.518519
#                2017     3.324176
#                2018     3.310345
#                2019     3.360215
#                2020     3.455331
#                2021     3.385542
# the-LEGO-Group 2010     2.500000
#                2011     2.307692
#                2012     2.500000
#                2013     3.058824
#                2014     3.425532
#                2015     3.215686
#                2016     3.581081
#                2017     3.130952
#                2018     3.070588
#                2019     3.371795
#                2020     3.916084
#                2021     3.850877

# %%
# # JW

best_lego = lego_loc_df.nlargest(10, "overall_rating")
best_lego
# Out:
#                                        overall_rating  work_life_balance  \
# location
# Aurora, IL                                        5.0                NaN
# Beachwood, OH                                     5.0                5.0
# Belsele, East Flanders, East Flanders             5.0                NaN
# Birmingham, England, England                      5.0                4.5
# Braintree, MA                                     5.0                5.0
# Canoga Park, CA                                   5.0                5.0
# Cardiff, Wales, Wales                             5.0                4.0
# Cicero, NY                                        5.0                3.0
# Cincinnati, OH                                    5.0                5.0
# Columbia, MD                                      5.0                NaN
#
#                                        culture_values
# location
# Aurora, IL                                        NaN
# Beachwood, OH                                     5.0
# Belsele, East Flanders, East Flanders             NaN
# Birmingham, England, England                      4.0
# Braintree, MA                                     5.0
# Canoga Park, CA                                   5.0
# Cardiff, Wales, Wales                             5.0
# Cicero, NY                                        3.0
# Cincinnati, OH                                    5.0
# Columbia, MD                                      5.0

# %%
best_accenture = accenture_loc_df.nlargest(10, "overall_rating")
best_accenture
# Out:
#                                                     overall_rating  \
# location
# Belfast, Northern Ireland, Northern Ireland                    5.0
# Briston, England, England                                      5.0
# Farnborough, Hampshire, South East England, Eng...             5.0
# Frankfurt am Main                                              5.0
# Haywards Heath, England, England                               5.0
# Highbury, England, England                                     5.0
# Lakeland, FL                                                   5.0
# Mansfield, MA                                                  5.0
# Mill Valley, CA                                                5.0
# Morpeth, England, England                                      5.0
#
#                                                     work_life_balance  \
# location
# Belfast, Northern Ireland, Northern Ireland                       5.0
# Briston, England, England                                         3.0
# Farnborough, Hampshire, South East England, Eng...                NaN
# Frankfurt am Main                                                 3.0
# Haywards Heath, England, England                                  3.0
# Highbury, England, England                                        5.0
# Lakeland, FL                                                      5.0
# Mansfield, MA                                                     5.0
# Mill Valley, CA                                                   NaN
# Morpeth, England, England                                         5.0
#
#                                                     culture_values
# location
# Belfast, Northern Ireland, Northern Ireland                    5.0
# Briston, England, England                                      4.0
# Farnborough, Hampshire, South East England, Eng...             NaN
# Frankfurt am Main                                              5.0
# Haywards Heath, England, England                               3.0
# Highbury, England, England                                     5.0
# Lakeland, FL                                                   5.0
# Mansfield, MA                                                  NaN
# Mill Valley, CA                                                NaN
# Morpeth, England, England                                      5.0

# %%
worst_lego = lego_loc_df.nsmallest(10, "overall_rating")
worst_lego
# Out:
#                      overall_rating  work_life_balance  culture_values
# location
# Fort Lauderdale, FL             1.0                4.0             1.0
# Hyderābād                       1.0                1.0             1.0
# Las Vegas, NV                   1.0                1.0             1.0
# Pittsburgh, PA                  1.0                1.0             1.0
# Pleasanton, CA                  1.0                1.0             1.0
# Vancouver, WA                   1.0                1.0             1.0
# Vernon, CA                      1.0                1.0             1.0
# West Hartford, CT               1.0                4.0             1.0
# Atlanta, GA                     2.0                2.0             2.0
# Milan                           2.0                3.0             4.0

# %%
worst_accenture = accenture_loc_df.nsmallest(10, "overall_rating")
worst_accenture
# Out:
#                                               overall_rating  \
# location
# Liverpool, England, England                              1.0
# Los Angeles, CA                                          1.0
# Poole, England, England                                  1.0
# Winnersh, England, England                               1.0
# Anacortes, WA                                            2.0
# Boston, MA                                               2.0
# Cambridge, East of England, England, England             2.0
# Gateshead, England, England                              2.0
# Trafford Park, England, England                          2.0
# Gurgaon, Haryana, Haryana                                2.5
#
#                                               work_life_balance  \
# location
# Liverpool, England, England                                 1.0
# Los Angeles, CA                                             2.0
# Poole, England, England                                     1.0
# Winnersh, England, England                                  1.0
# Anacortes, WA                                               1.0
# Boston, MA                                                  1.0
# Cambridge, East of England, England, England                3.0
# Gateshead, England, England                                 2.0
# Trafford Park, England, England                             3.0
# Gurgaon, Haryana, Haryana                                   4.0
#
#                                               culture_values
# location
# Liverpool, England, England                              1.0
# Los Angeles, CA                                          2.0
# Poole, England, England                                  NaN
# Winnersh, England, England                               2.0
# Anacortes, WA                                            NaN
# Boston, MA                                               1.0
# Cambridge, East of England, England, England             2.0
# Gateshead, England, England                              4.0
# Trafford Park, England, England                          NaN
# Gurgaon, Haryana, Haryana                                3.0

# %%
# # NM
firm_group_rating_yearly = firm_group_rating_yearly.fillna(0)
firm_group_rating_yearly
# Out:
#                      overall_rating  work_life_balance  culture_values  \
# firm           year
# Accenture      2008        3.151515           2.757576        0.000000
#                2009        3.138889           3.055556        0.000000
#                2010        3.088889           2.888889        0.000000
#                2011        3.095238           3.142857        0.000000
#                2012        3.530303           2.909091        3.309524
#                2013        3.814815           2.935897        3.779221
#                2014        3.500000           2.887500        3.362500
#                2015        3.717791           2.770701        3.576923
#                2016        3.844221           3.100000        3.788360
#                2017        3.641711           3.033149        3.549451
#                2018        3.626667           3.055172        3.655172
#                2019        3.801020           3.091398        3.745946
#                2020        3.885714           3.158501        3.755747
#                2021        3.830317           3.093093        3.702703
# the-LEGO-Group 2010        4.000000           4.000000        0.000000
#                2011        2.692308           3.076923        0.000000
#                2012        3.200000           3.357143        3.500000
#                2013        3.571429           4.000000        4.000000
#                2014        3.882353           3.617021        4.148936
#                2015        3.714286           3.705882        4.019231
#                2016        4.068966           3.710526        4.381579
#                2017        3.639175           3.977011        4.174419
#                2018        3.670103           3.816092        4.080460
#                2019        4.104651           4.128205        4.397436
#                2020        4.373418           4.361111        4.510490
#                2021        4.297872           4.061404        4.443478
#
#                      diversity_inclusion  career_opp  comp_benefits  \
# firm           year
# Accenture      2008             0.000000    3.212121       3.000000
#                2009             0.000000    3.083333       3.194444
#                2010             0.000000    3.133333       2.866667
#                2011             0.000000    3.000000       3.047619
#                2012             0.000000    3.696970       3.318182
#                2013             0.000000    3.820513       3.512821
#                2014             0.000000    3.775000       3.387500
#                2015             0.000000    3.735849       3.356688
#                2016             0.000000    3.910995       3.636842
#                2017             0.000000    3.823204       3.532967
#                2018             0.000000    3.737931       3.489655
#                2019             0.000000    3.881081       3.725806
#                2020             4.075188    3.968571       3.644699
#                2021             4.087879    3.873874       3.571856
# the-LEGO-Group 2010             0.000000    4.000000       2.500000
#                2011             0.000000    2.153846       2.384615
#                2012             0.000000    2.785714       3.000000
#                2013             0.000000    3.058824       3.176471
#                2014             0.000000    3.085106       3.355556
#                2015             0.000000    2.961538       3.215686
#                2016             0.000000    3.173333       3.653333
#                2017             0.000000    3.058140       3.534884
#                2018             0.000000    2.988506       3.436782
#                2019             0.000000    3.153846       3.740260
#                2020             4.050000    3.654930       4.062937
#                2021             4.241071    3.547826       4.061404
#
#                      senior_mgmt
# firm           year
# Accenture      2008     3.000000
#                2009     2.916667
#                2010     2.933333
#                2011     3.238095
#                2012     3.242424
#                2013     3.363636
#                2014     3.225000
#                2015     3.303226
#                2016     3.518519
#                2017     3.324176
#                2018     3.310345
#                2019     3.360215
#                2020     3.455331
#                2021     3.385542
# the-LEGO-Group 2010     2.500000
#                2011     2.307692
#                2012     2.500000
#                2013     3.058824
#                2014     3.425532
#                2015     3.215686
#                2016     3.581081
#                2017     3.130952
#                2018     3.070588
#                2019     3.371795
#                2020     3.916084
#                2021     3.850877

# %%
# # NM
sns.relplot(data = firm_group_rating_yearly, x = "year", y = "overall_rating", hue = "firm", kind="line")
plt.xticks(rotation=60)
plt.title('Yearly Change Overall Rating By Firm')
plt.xlabel('Year')
plt.ylabel('Overall Rating')
plt.show()

# %%
plt.plot(worst_accenture)
plt.xticks(rotation=90)
plt.legend(worst_accenture.columns,loc='best')
plt.title("Worst Accenture Locations")
plt.show()

# %%
plt.plot(best_accenture)
plt.xticks(rotation=90)
plt.legend(best_accenture.columns,loc='best')
plt.title("Best Accenture Locations")
plt.show()

# %%
plt.plot(worst_lego)
plt.xticks(rotation=90)
plt.legend(worst_lego.columns,loc='best')
plt.title("Worst Lego Locations")
plt.show()

# %%
plt.plot(best_lego)
plt.xticks(rotation=90)
plt.legend(best_lego.columns,loc='best')
plt.title("Best Lego Locations")
plt.show()
